# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanishk934/Kanishk934/blob/main/numpy_first_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# To install a Python library, use the `!pip install` command followed by the package name. For example, to install `pandas`:

# %%
# !pip install pandas

# %%
# !pip install numpy

# %% [markdown]
# After installation, you can import and use the library in your code.

# %%
import numpy as np

print(np.__version__)
# Out:
# 2.0.2

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print(arr)
# Out:
# [10 20 30 40 50]

# %% [markdown]
# You can connect your Colab notebook to GitHub directly from the Colab interface.
#
# 1.  **Save a copy to GitHub**: Go to `File` > `Save a copy in GitHub...`.
# 2.  This will open a dialog where you can select your GitHub repository, provide a commit message, and choose the branch. You'll need to authorize Colab to access your GitHub account if you haven't already.
# 3.  Once saved, your `.ipynb` file will appear in your chosen GitHub repository.
